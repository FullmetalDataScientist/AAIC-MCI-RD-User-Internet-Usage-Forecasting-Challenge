# %% [markdown]
# <a href="https://colab.research.google.com/github/FullmetalDataScientist/AAIC-MCI-RD-User-Internet-Usage-Forecasting-Challenge/blob/main/AAIC2021_MCI_RD_UIUF_Challenge.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages('forecast', repos='http://cran.rstudio.com/')
install.packages('h2o', repos='http://cran.rstudio.com/')
install.packages('mlr', repos='http://cran.rstudio.com/')
install.packages('data.table', repos='http://cran.rstudio.com/')
install.packages('prophet', repos='http://cran.rstudio.com/')
install.packages('modeltime', repos='http://cran.rstudio.com/')
install.packages('parsnip', repos='http://cran.rstudio.com/')
install.packages('tidymodels', repos='http://cran.rstudio.com/')
install.packages('earth', repos='http://cran.rstudio.com/')
install.packages('keras', repos='http://cran.rstudio.com/')

# %%
data <- read.csv('Train+test(Ordered).csv')
test <- read.csv('MCIRD_aaic2021_week1_week2.csv')

#############Adding Week Days

d1 <- c("(n+3)04", "(n+2)28", "(n+2)21", "(n+2)14", "(n+2)07", "(n+1)31", "(n+1)24", "(n+1)17", "(n+1)10", "(n+1)03", "(n)27", "(n)20", "(n)13", "(n)06")
d2 <- c("(n+3)03", "(n+2)27", "(n+2)20", "(n+2)13", "(n+2)06", "(n+1)30", "(n+1)23", "(n+1)16", "(n+1)09", "(n+1)02", "(n)26", "(n)19", "(n)12", "(n)05")
d3 <- c("(n+3)02", "(n+2)26", "(n+2)19", "(n+2)12", "(n+2)05", "(n+1)29", "(n+1)22", "(n+1)15", "(n+1)08", "(n+1)01", "(n)25", "(n)18", "(n)11", "(n)04")
d4 <- c("(n+3)01", "(n+2)25", "(n+2)18", "(n+2)11", "(n+2)04", "(n+1)28", "(n+1)21", "(n+1)14", "(n+1)07", "(n)31", "(n)24", "(n)17", "(n)10", "(n)03")
d5 <- c("(n+2)31", "(n+2)24", "(n+2)17", "(n+2)10", "(n+2)03", "(n+1)27", "(n+1)20", "(n+1)13", "(n+1)06", "(n)30", "(n)23", "(n)16", "(n)09", "(n)02")
d6 <- c("(n+2)30", "(n+2)23", "(n+2)16", "(n+2)09", "(n+2)02", "(n+1)26", "(n+1)19", "(n+1)12", "(n+1)05", "(n)29", "(n)22", "(n)15", "(n)08", "(n)01")
d7 <- c("(n+2)29", "(n+2)22", "(n+2)15", "(n+2)08", "(n+2)01", "(n+1)25", "(n+1)18", "(n+1)11", "(n+1)04", "(n)28", "(n)21", "(n)14", "(n)07")
l <- length(data$day)
Week_Days <- rep(0, l)
data <- cbind(data, Week_Days)

for (i in 1:l) {
  for (d in d1) {
    if (data$day[i] == d) data$Week_Days[i] <- "D07"
  }
}

for (i in 1:l) {
  for (d in d2) {
    if (data$day[i] == d) data$Week_Days[i] <- "D06"
  }
}

for (i in 1:l) {
  for (d in d3) {
    if (data$day[i] == d) data$Week_Days[i] <- "D05"
  }
}

for (i in 1:l) {
  for (d in d4) {
    if (data$day[i] ==d ) data$Week_Days[i] <- "D04"
  }
}

for (i in 1:l) {
  for (d in d5) {
    if (data$day[i] ==d ) data$Week_Days[i] <- "D03"
  }
}

for (i in 1:l) {
  for (d in d6) {
    if (data$day[i] ==d ) data$Week_Days[i] <- "D02"
  }
}

for (i in 1:l) {
  for (d in d7) {
    if (data$day[i] ==d ) data$Week_Days[i] <- "D01"
  }
}

write.csv(data, 'Train_Week_Days_Added.csv', row.names = FALSE)
#############Adding Weeks

w1 <- c("(n+2)07", "(n+2)06", "(n+2)05", "(n+2)04", "(n+2)03", "(n+2)02", "(n+2)01")
w2 <- c("(n+1)31", "(n+1)30", "(n+1)29", "(n+1)28", "(n+1)27", "(n+1)26", "(n+1)25")
w3 <- c("(n+1)24", "(n+1)23", "(n+1)22", "(n+1)21", "(n+1)20", "(n+1)19", "(n+1)18")
w4 <- c("(n+1)17", "(n+1)16", "(n+1)15", "(n+1)14", "(n+1)13", "(n+1)12", "(n+1)11")
w5 <- c("(n+1)10", "(n+1)09", "(n+1)08", "(n+1)07", "(n+1)06", "(n+1)05", "(n+1)04")
w6 <- c("(n+1)03", "(n+1)02", "(n+1)01", "(n)31", "(n)30", "(n)29", "(n)28")
w7 <- c("(n)27", "(n)26", "(n)25", "(n)24", "(n)23", "(n)22", "(n)21")
w8 <- c("(n)20", "(n)19", "(n)18", "(n)17", "(n)16", "(n)15", "(n)14")
w9 <- c("(n)13", "(n)12", "(n)11", "(n)10", "(n)09", "(n)08", "(n)07")
w10 <- c("(n)06", "(n)05", "(n)04", "(n)03", "(n)02", "(n)01")
w11 <- c("(n+2)08", "(n+2)09", "(n+2)10", "(n+2)11", "(n+2)12", "(n+2)13", "(n+2)14")
w12 <- c("(n+2)15", "(n+2)16", "(n+2)17", "(n+2)18", "(n+2)19", "(n+2)20", "(n+2)21")
w13 <- c("(n+2)22", "(n+2)23", "(n+2)24", "(n+2)25", "(n+2)26", "(n+2)27", "(n+2)28", "(n+2)29", "(n+2)30", "(n+2)31")
Weeks <- rep(0, l)
data <- cbind(data, Weeks)

for (i in 1:l) {
  for (w in w1) {
    if (data$day[i] == w) data$Weeks[i] <- "W10"
  }
}

for (i in 1:l) {
  for (w in w2) {
    if (data$day[i] == w) data$Weeks[i] <- "W09"
  }
}

for (i in 1:l) {
  for (w in w3) {
    if (data$day[i] == w) data$Weeks[i] <- "W08"
  }
}

for (i in 1:l) {
  for (w in w4) {
    if (data$day[i] == w) data$Weeks[i] <- "W07"
  }
}

for (i in 1:l) {
  for (w in w5) {
    if (data$day[i] == w) data$Weeks[i] <- "W06"
  }
}

for (i in 1:l) {
  for (w in w6) {
    if (data$day[i] == w) data$Weeks[i] <- "W05"
  }
}

for (i in 1:l) {
  for (w in w7) {
    if (data$day[i] == w) data$Weeks[i] <- "W04"
  }
}

for (i in 1:l) {
  for (w in w8) {
    if (data$day[i] ==w ) data$Weeks[i] <- "W03"
  }
}

for (i in 1:l) {
  for (w in w9) {
    if (data$day[i] == w) data$Weeks[i] <- "W02"
  }
}

for (i in 1:l) {
  for (w in w10) {
    if (data$day[i] == w) data$Weeks[i] <- "W01"
  }
}

write.csv(data, 'Train_Weeks_Added.csv', row.names = FALSE)
#############Adding Months
m0 <- c("W01", "W02")
m1 <- c("W03", "W04", "W05", "W06")
m2 <- c("W07", "W08", "W09", "W10")

for (i in 1:662) {
  for (m in m0) {
    if (data$Week[i] == m) data$registration_province[i] <- "M00"
  }
}

for (i in 1:662) {
  for (m in m1) {
    if (data$Week[i] == m) data$registration_province[i] <- "M01"
  }
}

for (i in 1:662) {
  for (m in m2) {
    if (data$Week[i] == m) data$registration_province[i] <- "M02"
  }
}

write.csv(data, 'Train_Months_Added.csv', row.names = FALSE)

# %%
smape <- function(actual, pred){
  score <- 0
  l <- length(pred)
  for (i in 1:l) {
    score <- score+abs(pred[i] - actual[i])/(abs(actual[i]) + abs(pred[i]))
  }
  return(1-score/l)
}
#############Model 1: Overall Mean per User
data <- read.csv('Train+Week1(Ordered).csv')
test <- read.csv('MCIRD_aaic2021_test_week2.csv')
#data <- read.csv('MCIRD_aaic2021_train.csv')
#test <- read.csv('MCIRD_aaic2021_test_week1_with_target.csv')

lt <- length(test$subscriber_ecid)
ld <- length(data$subscriber_ecid)
m <- aggregate(data_usage_volume ~ subscriber_ecid, data = data, FUN = "mean")
id <- m$subscriber_ecid
OM <- rep(0, lt)
test <- cbind(test, OM)

for (j in 1:lt) {
  for (i in id) {
    if (test$subscriber_ecid[j] == i) test$OM[j] <- m[m$subscriber_ecid==i, 2]
  }
}


ZeroUse <- as.numeric(-0.0139766307813943)
for (i in 1:lt) {
  if (test$is_data_usage_nonzero[i] == 0) test$OM[i] <- ZeroUse
}

ind <- c()
for (j in 1:lt) {
  if (test$data_cash_expenses[j] == 0 & test$nonpackage_data_expenses[j] != 0 & test$package_data_noncash_expenses[j] == 0) ind[j] <- j
}

ind <- ind[!is.na(ind)]

cons <- 0.036890546
for (i in ind) {
  test$OM[i] <- test$nonpackage_data_expenses[i]*cons/4510.638 + ZeroUse
}

write.csv(test, 'Model1(Week2).csv', row.names = FALSE)

# %%
#############Model 2: Mean per Day of the Week
data <- read.csv('Train_Week_Days_Added.csv')
test <- read.csv('Test_Week_Days_Added.csv')
#data <- read.csv('Train_Weeks_Added.csv')
#test <- read.csv('Test1_Weeks_Added.csv')

m <- aggregate(data_usage_volume ~ subscriber_ecid + Week_Days, data = data, FUN = "mean")
id <- m$subscriber_ecid
day <- c("D01", "D02", "D03", "D04", "D05", "D06", "D07")
lt <- length(test$subscriber_ecid)
ld <- length(data$subscriber_ecid)
DbDM <- rep(0, lt)
test <- cbind(test, DbDM)

for (j in 1:lt) {
  for (i in id) {
    for (d in day) {
      if (test$subscriber_ecid[j] == i & test$Week_Days[j] == d) test$DbDM[j] <- m[(m$subscriber_ecid==i & m$Week_Days==d), 3]
    }
  }
}


ZeroUse <- as.numeric(-0.0139766307813943)
for (i in 1:lt) {
  if (test$is_data_usage_nonzero[i] == 0) test$DbDM[i] <- ZeroUse
}

ind <- c()
for (j in 1:lt) {
  if (test$data_cash_expenses[j] == 0 & test$nonpackage_data_expenses[j] != 0 & test$package_data_noncash_expenses[j] == 0) ind[j] <- j
}

ind <- ind[!is.na(ind)]

cons <- 0.036890546
for (i in ind) {
  test$DbDM[i] <- test$nonpackage_data_expenses[i]*cons/4510.638 + ZeroUse
}

write.csv(test, 'Model2(Week2).csv', row.names = FALSE)

# %%
#############Model 3 & 4: Overall Mean (Last 4 Weeks & Last 2 Weeks)
data<-read.csv(file.choose())
test<-read.csv(file.choose())

wind <- c()
for (i in 1:1986) {
  if (data$Weeks[i] == "W08") wind[i] <- i
}
wind <- wind[!is.na(wind)]
data <- data[-wind,]
addd<-"C:/Users/TS/Desktop/MCI-RD-aaic-UIUF/Train_Last_2_Weeks.csv"
write.csv(data,file=addd, row.names = FALSE)

m <- aggregate(data_usage_volume~subscriber_ecid, data = data, FUN = "mean")
id <- m$subscriber_ecid

for (j in 1:662) {
  for (i in id) {
    if (test$subscriber_ecid[j] == i) test$subscriber_age[j] <- m[m$subscriber_ecid==i, 2]
  }
}


ZeroUse <- as.numeric(-0.0139766307813943)
for (i in 1:662) {
  if (test$is_data_usage_nonzero[i] == 0) test$subscriber_age[i] <- ZeroUse
}

ind <- c()
for (j in 1:662) {
  if (test$data_cash_expenses[j] == 0 & test$nonpackage_data_expenses[j] != 0 & test$package_data_noncash_expenses[j] == 0) ind[j] <- j
}

ind <- ind[!is.na(ind)]

cons <- 0.036890546
for (i in ind) {
  test$subscriber_age[i] <- test$nonpackage_data_expenses[i]*cons/4510.638 + ZeroUse
}

write.csv(test, 'Model3(week1).csv', row.names = FALSE)

# %%
#############Model 5 to 13: SES, Holt-Winter's, ARIMA, TBATS, ETS, Theta, NNET, BAGGED & SplineF
require(forecast)

data <- read.csv('Train+test(Ordered).csv')
test <- read.csv('MCIRD_aaic2021_test_week2.csv')
#data <- read.csv('MCIRD_aaic2021_train.csv')
#test <- read.csv('MCIRD_aaic2021_test_week1_with_target.csv')

lt <- length(test$subscriber_ecid)
TBATS <- rep(0, lt)
ARIMA <- rep(0, lt)
Holts <- rep(0, lt)
SES <- rep(0, lt)
ETS <- rep(0, lt)
THETA <- rep(0, lt)
NNET <- rep(0, lt)
BAGGED <- rep(0, lt)
SPLINEF <- rep(0, lt)
test <- cbind(test, TBATS, ARIMA, Holts, SES, ETS, THETA, NNET, BAGGED, SPLINEF)
id <- unique(test$subscriber_ecid)

for (i in id) {
  data_ts <- ts(data$data_usage_volume[data$subscriber_ecid == i])
  l <- length(test$subscriber_age[test$subscriber_ecid == i])
  TBATS_model <- tbats(data_ts)
  t <- forecast(TBATS_model, h = l)
  test$TBATS[test$subscriber_ecid == i] <- as.numeric(t$mean)
  ARIMA_model <- auto.arima(data_ts)
  a <- forecast(ARIMA_model, h = l)
  test$ARIMA[test$subscriber_ecid == i] <- as.numeric(a$mean)
  Holts_model <- holt(data_ts)
  h <- forecast(Holts_model, h = l)
  test$Holts[test$subscriber_ecid == i] <- as.numeric(h$mean)
  SES_model <- ses(data_ts)
  s <- forecast(SES_model, h = l)
  test$SES[test$subscriber_ecid == i] <- as.numeric(s$mean)
  ETS_model <- ets(data_ts)
  s <- forecast(ETS_model, h = l)
  test$ETS[test$subscriber_ecid == i] <- as.numeric(s$mean)
  THETA_model <- thetaf(data_ts)
  s <- forecast(THETA_model, h = l)
  test$THETA[test$subscriber_ecid == i] <- as.numeric(s$mean)
  NNET_model <- nnetar(data_ts)
  s <- forecast(NNET_model, h = l)
  test$NNET[test$subscriber_ecid == i] <- as.numeric(s$mean)
  BAGGED_model <- baggedModel(data_ts)
  s <- forecast(BAGGED_model, h = l)
  test$BAGGED[test$subscriber_ecid == i] <- as.numeric(s$mean)
  SPLINE_model <- splinef(data_ts)
  s <- forecast(SPLINE_model, h = l)
  test$SPLINEF[test$subscriber_ecid == i] <- as.numeric(s$mean)
}

ZeroUse <- as.numeric(-0.0139766307813943)
for (i in 1:lt) {
  if (test$is_data_usage_nonzero[i] == 0) {
    test$SPLINEF[i] <- ZeroUse
    test$BAGGED[i] <- ZeroUse
    test$NNET[i] <- ZeroUse
    test$THETA[i] <- ZeroUse
    test$ETS[i] <- ZeroUse
    test$SES[i] <- ZeroUse
    test$Holts[i] <- ZeroUse
    test$ARIMA[i] <- ZeroUse
    test$TBATS[i] <- ZeroUse
  }
}

ind <- c()
for (j in 1:lt) {
  if (test$data_cash_expenses[j] == 0 & test$nonpackage_data_expenses[j] != 0 & test$package_data_noncash_expenses[j] == 0) ind[j] <- j
}

ind <- ind[!is.na(ind)]

cons <- 0.036890546
for (i in ind) {
  test$SPLINEF[i] <- test$nonpackage_data_expenses[i]*cons/4510.638 + ZeroUse
  test$BAGGED[i] <- test$nonpackage_data_expenses[i]*cons/4510.638 + ZeroUse
  test$NNET[i] <- test$nonpackage_data_expenses[i]*cons/4510.638 + ZeroUse
  test$THETA[i] <- test$nonpackage_data_expenses[i]*cons/4510.638 + ZeroUse
  test$ETS[i] <- test$nonpackage_data_expenses[i]*cons/4510.638 + ZeroUse
  test$SES[i] <- test$nonpackage_data_expenses[i]*cons/4510.638 + ZeroUse
  test$Holts[i] <- test$nonpackage_data_expenses[i]*cons/4510.638 + ZeroUse
  test$ARIMA[i] <- test$nonpackage_data_expenses[i]*cons/4510.638 + ZeroUse
  test$TBATS[i] <- test$nonpackage_data_expenses[i]*cons/4510.638 + ZeroUse
}

write.csv(test, 'Model5-13(Week2).csv', row.names = FALSE)

# %%
#############Model14: GBM
library(data.table)
library(mlr)
require(h2o)

localH2o <- h2o.init(nthreads = -1)

data <- read.csv('MCIRD_aaic2021_train.csv')
test <- read.csv('MCIRD_aaic2021_test_week1.csv')
#data <- read.csv('Train+test(Ordered).csv')
#test <- read.csv('MCIRD_aaic2021_test_week2.csv')

id <- unique(test$subscriber_ecid)
lt <- length(test$subscriber_ecid)
ld <- length(data$subscriber_ecid)

for (j in 1:ld){
  set.seed(j)
  data$data_usage_volume[j] <- data$data_usage_volume[j] + runif(1,0.0001,0.001)
}

lags <- function(x){
  lagB <- c(NA, x)
  lagA <- c(x, NA)
  DF <- as.data.frame(cbind(lagB, lagA))
  colnames(DF) <- c( paste0('n-', 1), 'n')
  return(DF)
}

GBM <- rep(0, lt)
test <- cbind(test, GBM)

for (i in id){
  train <- data$data_usage_volume[data$subscriber_ecid == i]
  l <- length(train)
  lu <- length(test$day[test$subscriber_ecid == i])
  train <- lags(train)
  pred <- train[(l+1), ]
  train <- train[-c(1, l+1), ]
  forecastuser <- rep(0, lu)
  setDT(train)
  setDT(pred)
  trainh2o <- as.h2o(train)
  predh2o <- as.h2o(pred)

  y <- "n"
  x <- setdiff(colnames(trainh2o), y)

  GBM_Model <- h2o.gbm(x = x,
                       y = y,
                       training_frame = trainh2o,
                       seed = 1,
                       ntrees = 1000,
                       learn_rate = 0.03,
                       stopping_rounds = 5,
                       stopping_tolerance = 1e-4,
                       stopping_metric = "RMSE",
                       score_tree_interval = 10,
                       max_depth = 13)

  for (d in 1:lu){
    forch2o <- h2o.predict(GBM_Model, predh2o)
    forecastuser[d] <- as.numeric(forch2o[1,1])
    predh2o[1,1] <- as.numeric(forch2o[1,1])
  }
  test$GBM[test$subscriber_ecid==i] <- as.vector(forecastuser)
}

ZeroUse <- as.numeric(-0.0139766307813943)
for (i in 1:lt) {
  if (test$is_data_usage_nonzero[i] == 0) test$GBM[i] <- ZeroUse
}

ind <- c()
for (j in 1:lt) {
  if (test$data_cash_expenses[j] == 0 & test$nonpackage_data_expenses[j] != 0 & test$package_data_noncash_expenses[j] == 0) ind[j] <- j
}

ind <- ind[!is.na(ind)]

cons <- 0.036890546
for (i in ind) {
  test$GBM[i] <- test$nonpackage_data_expenses[i]*cons/4510.638 + ZeroUse
}

write.csv(test, 'Model14(GBM).csv', row.names = FALSE)

# %%
#############Model 15: XGBoost
library(data.table)
library(mlr)
require(h2o)

localH2o <- h2o.init(nthreads = -1)

data <- read.csv('MCIRD_aaic2021_train.csv')
test <- read.csv('MCIRD_aaic2021_test_week1.csv')
#data <- read.csv('Train+test(Ordered).csv')
#test <- read.csv('MCIRD_aaic2021_test_week2.csv')

id <- unique(test$subscriber_ecid)
lt <- length(test$subscriber_ecid)
ld <- length(data$subscriber_ecid)

for (j in 1:ld){
  set.seed(j)
  data$data_usage_volume[j] <- data$data_usage_volume[j] + runif(1,0.0001,0.001)
}

lags <- function(x){
  lagB <- c(NA, x)
  lagA <- c(x, NA)
  DF <- as.data.frame(cbind(lagB, lagA))
  colnames(DF) <- c( paste0('n-', 1), 'n')
  return(DF)
}

XGB <- rep(0, lt)
test <- cbind(test, XGB)

for (i in id){
  train <- data$data_usage_volume[data$subscriber_ecid == i]
  l <- length(train)
  lu <- length(test$day[test$subscriber_ecid == i])
  train <- lags(train)
  pred <- train[(l+1), ]
  train <- train[-c(1, l+1), ]
  forecastuser <- rep(0, lu)
  setDT(train)
  setDT(pred)
  trainh2o <- as.h2o(train)
  predh2o <- as.h2o(pred)

  y <- "n"
  x <- setdiff(colnames(trainh2o), y)

  XGB_Model <- h2o.xgboost(x = x,
                           y = y,
                           training_frame = trainh2o,
                           seed = 1,
                           ntrees = 10000,
                           learn_rate = 0.01,
                           stopping_rounds = 5,
                           stopping_tolerance = 1e-4,
                           stopping_metric = "RMSE",
                           score_tree_interval = 10)

  for (d in 1:lu){
    forch2o <- h2o.predict(XGB_Model, predh2o)
    forecastuser[d] <- as.numeric(forch2o[1,1])
    predh2o[1,1] <- as.numeric(forch2o[1,1])
  }
  test$XGB[test$subscriber_ecid==i] <- as.vector(forecastuser)
}

ZeroUse <- as.numeric(-0.0139766307813943)
for (i in 1:lt) {
  if (test$is_data_usage_nonzero[i] == 0) test$XGB[i] <- ZeroUse
}

ind <- c()
for (j in 1:lt) {
  if (test$data_cash_expenses[j] == 0 & test$nonpackage_data_expenses[j] != 0 & test$package_data_noncash_expenses[j] == 0) ind[j] <- j
}

ind <- ind[!is.na(ind)]

cons <- 0.036890546
for (i in ind) {
  test$XGB[i] <- test$nonpackage_data_expenses[i]*cons/4510.638 + ZeroUse
}

write.csv(test, 'Model15(XGBoost).csv', row.names = FALSE)

# %%
#############Model 16: Random Forest
library(data.table)
library(mlr)
require(h2o)

localH2o <- h2o.init(nthreads = -1)

#data <- read.csv('MCIRD_aaic2021_train.csv')
#test <- read.csv('MCIRD_aaic2021_test_week1.csv')
data <- read.csv('Train+Week1(Ordered).csv')
test <- read.csv('MCIRD_aaic2021_test_week2.csv')

id <- unique(test$subscriber_ecid)
lt <- length(test$subscriber_ecid)
ld <- length(data$subscriber_ecid)

for (j in 1:ld){
  set.seed(j)
  data$data_usage_volume[j] <- data$data_usage_volume[j] + runif(1,0.0001,0.001)
}

lags <- function(x){
  lagB <- c(NA, x)
  lagA <- c(x, NA)
  DF <- as.data.frame(cbind(lagB, lagA))
  colnames(DF) <- c( paste0('n-', 1), 'n')
  return(DF)
}

RF <- rep(0, lt)
test <- cbind(test, RF)

for (i in id){
  train <- data$data_usage_volume[data$subscriber_ecid == i]
  l <- length(train)
  lu <- length(test$day[test$subscriber_ecid == i])
  train <- lags(train)
  pred <- train[(l+1), ]
  train <- train[-c(1, l+1), ]
  forecastuser <- rep(0, lu)
  setDT(train)
  setDT(pred)
  trainh2o <- as.h2o(train)
  predh2o <- as.h2o(pred)

  y <- "n"
  x <- setdiff(colnames(trainh2o), y)

  RF_Model <- h2o.randomForest(x = x,
                               y = y,
                               training_frame = trainh2o,
                               mtries = 1,
                               model_id = "rf_model",
                               ntrees = 200,
                               seed = 1)

  for (d in 1:lu){
    forch2o <- h2o.predict(RF_Model, predh2o)
    forecastuser[d] <- as.numeric(forch2o[1,1])
    predh2o[1,1] <- as.numeric(forch2o[1,1])
  }
  test$RF[test$subscriber_ecid==i] <- as.vector(forecastuser)
}

ZeroUse <- as.numeric(-0.0139766307813943)
for (i in 1:lt) {
  if (test$is_data_usage_nonzero[i] == 0) {
    test$RF[i] <- ZeroUse
  }
}

ind <- c()
for (j in 1:lt) {
  if (test$data_cash_expenses[j] == 0 & test$nonpackage_data_expenses[j] != 0 & test$package_data_noncash_expenses[j] == 0) ind[j] <- j
}

ind <- ind[!is.na(ind)]

cons <- 0.036890546
for (i in ind) {
  test$RF[i] <- test$nonpackage_data_expenses[i]*cons/4510.638 + ZeroUse
}
smape(test$RF, test2$data_usage_volume)
write.csv(test, 'Model16(RF).csv', row.names = FALSE)

# %%
#############Model 17: Neural Nets
library(data.table)
library(mlr)
require(h2o)

localH2o <- h2o.init(nthreads = -1)

#data <- read.csv('MCIRD_aaic2021_train.csv')
#test <- read.csv('MCIRD_aaic2021_test_week1.csv')
data <- read.csv('Train+Week1(Ordered).csv')
test <- read.csv('MCIRD_aaic2021_test_week2.csv')

id <- unique(test$subscriber_ecid)
lt <- length(test$subscriber_ecid)
ld <- length(data$subscriber_ecid)

for (j in 1:ld){
  set.seed(j)
  data$data_usage_volume[j] <- data$data_usage_volume[j] + runif(1,0.0001,0.001)
}

lags <- function(x){
  lagB <- c(NA, x)
  lagA <- c(x, NA)
  DF <- as.data.frame(cbind(lagB, lagA))
  colnames(DF) <- c( paste0('n-', 1), 'n')
  return(DF)
}

DNN <- rep(0, lt)
test <- cbind(test, DNN)

for (i in id){
  train <- data$data_usage_volume[data$subscriber_ecid == i]
  l <- length(train)
  lu <- length(test$day[test$subscriber_ecid == i])
  train <- lags(train)
  pred <- train[(l+1), ]
  train <- train[-c(1, l+1), ]
  forecastuser <- rep(0, lu)
  setDT(train)
  setDT(pred)
  trainh2o <- as.h2o(train)
  predh2o <- as.h2o(pred)

  y <- "n"
  x <- setdiff(colnames(trainh2o), y)

  DNN_Model <- h2o.deeplearning(x = x,
                                y = y,
                                training_frame = trainh2o,
                                reproducible = TRUE,
                                standardize = T,
                                activation = "MaxoutWithDropout",
                                epochs = 100,
                                seed = 1,
                                hidden = 11)

  for (d in 1:lu){
    forch2o <- h2o.predict(DNN_Model, predh2o)
    forecastuser[d] <- as.numeric(forch2o[1,1])
    predh2o[1,1] <- as.numeric(forch2o[1,1])
  }
  test$DNN[test$subscriber_ecid==i] <- as.vector(forecastuser)
}

ZeroUse <- as.numeric(-0.0139766307813943)
for (i in 1:lt) {
  if (test$is_data_usage_nonzero[i] == 0) test$DNN[i] <- ZeroUse
}

ind <- c()
for (j in 1:lt) {
  if (test$data_cash_expenses[j] == 0 & test$nonpackage_data_expenses[j] != 0 & test$package_data_noncash_expenses[j] == 0) ind[j] <- j
}

ind <- ind[!is.na(ind)]

cons <- 0.036890546
for (i in ind) {
  test$DNN[i] <- test$nonpackage_data_expenses[i]*cons/4510.638 + ZeroUse
}
write.csv(test, 'Model17(MaxWD11).csv', row.names = FALSE)

# %%
#############Model 18: Prophet
library(prophet)
#data <- read.csv('Train+test(Ordered).csv')
#test <- read.csv('MCIRD_aaic2021_test_week2.csv')
data <- read.csv('MCIRD_aaic2021_train.csv')
test <- read.csv('MCIRD_aaic2021_test_week1_with_target.csv')

id <- unique(test$subscriber_ecid)
lt <- length(test$subscriber_ecid)
ld <- length(data$subscriber_ecid)
Proph <- rep(0, lt)
test <- cbind(test, Proph)

for (i in id){
  y <- ts(data$data_usage_volume[data$subscriber_ecid == i])
  l <- length(y)
  ds <- seq(from = as.Date("2017-01-01"), length.out = l, by = 'day')
  prophet_data <- cbind(ds, y)
  for(j in 1:l){
    prophet_data[j, 1] <- as.character(ds[j])
  }
  prophet_data <- as.data.frame(prophet_data)
  prophet_model <- prophet(prophet_data, growth = 'flat')
  pred <- test$day[test$subscriber_ecid == i]
  lp <- length(pred)
  future <- make_future_dataframe(prophet_model, periods = lp, freq = "day", include_history = FALSE)
  forecast <- predict(prophet_model, future)
  Proph <- as.vector(forecast['yhat'])
  test$Proph[test$subscriber_ecid==i] <- Proph[,1]
}

ZeroUse <- as.numeric(-0.0139766307813943)
for (i in 1:lt) {
  if (test$is_data_usage_nonzero[i] == 0) test$Proph[i] <- ZeroUse
}

ind <- c()
for (j in 1:lt) {
  if (test$data_cash_expenses[j] == 0 & test$nonpackage_data_expenses[j] != 0 & test$package_data_noncash_expenses[j] == 0) ind[j] <- j
}

ind <- ind[!is.na(ind)]

cons <- 0.036890546
for (i in ind) {
  test$Proph[i] <- test$nonpackage_data_expenses[i]*cons/4510.638 + ZeroUse
}

write.csv(test, 'Model18(Prophet_Flat).csv', row.names = FALSE)

# %%
#############Model 19: ARIMABoost
library(xgboost)
library(tidymodels)
library(modeltime)
library(tidyverse)
library(lubridate)
library(timetk)

#data <- read.csv('Train+test(Ordered).csv')
#test <- read.csv('MCIRD_aaic2021_test_week2.csv')
data <- read.csv('MCIRD_aaic2021_train.csv')
test <- read.csv('MCIRD_aaic2021_test_week1_with_target.csv')

id <- unique(test$subscriber_ecid)
lt <- length(test$subscriber_ecid)
ARBoost <- rep(0, lt)
test <- cbind(test, ARBoost)

for(i in id){
  y <- ts(data$data_usage_volume[data$subscriber_ecid == i])
  l <- length(y)
  ds <- seq(from = as.Date("2017-01-01"), length.out = l, by = 'day')
  ARB_data <- cbind(ds, y)
  ARB_data <- as_tibble(ARB_data)
  ARB_data$ds <- as.Date(ds)
  ARB_Model <- arima_boost(min_n = 2, learn_rate = 0.03) %>%
    set_engine(engine = "auto_arima_xgboost") %>%
    fit(y ~ ds + as.numeric(ds) + factor(month(ds, label = TRUE), ordered = F), data = ARB_data)
  models_tbl <- modeltime_table(ARB_Model)
  y <- ts(test$data_usage_volume[test$subscriber_ecid == i])
  lu <- length(y)
  ds <- seq(from = as.Date(ARB_data$ds[l]), length.out = lu, by = 'day')
  ARB_data_t <- cbind(ds, y)
  ARB_data_t <- as_tibble(ARB_data_t)
  ARB_data_t$ds <- as.Date(ds)
  calibration_tbl <- models_tbl %>%
    modeltime_calibrate(new_data = ARB_data_t)
  pred <- modeltime_forecast(calibration_tbl, new_data = ARB_data_t, actual_data = ARB_data)
  test$ARBoost[test$subscriber_ecid==i] <- as.vector(pred$.value[(l+1):(l+lu)])
}

ZeroUse <- as.numeric(-0.0139766307813943)
for (i in 1:lt) {
  if (test$is_data_usage_nonzero[i] == 0) test$ARBoost[i] <- ZeroUse
}

ind <- c()
for (j in 1:lt) {
  if (test$data_cash_expenses[j] == 0 & test$nonpackage_data_expenses[j] != 0 & test$package_data_noncash_expenses[j] == 0) ind[j] <- j
}

ind <- ind[!is.na(ind)]

cons <- 0.036890546
for (i in ind) {
  test$ARBoost[i] <- test$nonpackage_data_expenses[i]*cons/4510.638 + ZeroUse
}

smape(test$data_usage_volume, test$ARBoost)

write.csv(test, 'Model19(ARIMABoost).csv', row.names = FALSE)

# %%
#############Model 20: LR
library(xgboost)
library(tidymodels)
library(modeltime)
library(tidyverse)
library(lubridate)
library(timetk)

#data <- read.csv('Train+test(Ordered).csv')
#test <- read.csv('MCIRD_aaic2021_test_week2.csv')
data <- read.csv('MCIRD_aaic2021_train.csv')
test <- read.csv('MCIRD_aaic2021_test_week1_with_target.csv')

id <- unique(test$subscriber_ecid)
lt <- length(test$subscriber_ecid)

LR <- rep(0, lt)
test <- cbind(test, LR)

for(i in id){
  y <- ts(data$data_usage_volume[data$subscriber_ecid == i])
  l <- length(y)
  ds <- seq(from = as.Date("2017-01-01"), length.out = l, by = 'day')
  LR_data <- cbind(ds, y)
  LR_data <- as_tibble(LR_data)
  LR_data$ds <- as.Date(ds)
  LR_Model <- linear_reg() %>%
    set_engine("lm") %>%
    fit(y ~ as.numeric(ds) + factor(month(ds, label = TRUE), ordered = FALSE), data = LR_data)
  models_tbl <- modeltime_table(LR_Model)
  y <- ts(test$data_usage_volume[test$subscriber_ecid == i])
  lu <- length(y)
  ds <- seq(from = as.Date(LR_data$ds[l]), length.out = lu, by = 'day')
  LR_data_t <- cbind(ds, y)
  LR_data_t <- as_tibble(LR_data_t)
  LR_data_t$ds <- as.Date(ds)
  calibration_tbl <- models_tbl %>%
    modeltime_calibrate(new_data = LR_data_t, quiet = FALSE)
  pred <- modeltime_forecast(calibration_tbl, new_data = LR_data_t, actual_data = LR_data)
  test$LR[test$subscriber_ecid==i] <- as.vector(pred$.value[(l+1):(l+lu)])
}

ZeroUse <- as.numeric(-0.0139766307813943)
for (i in 1:lt) {
  if (test$is_data_usage_nonzero[i] == 0) test$LR[i] <- ZeroUse
}

ind <- c()
for (j in 1:lt) {
  if (test$data_cash_expenses[j] == 0 & test$nonpackage_data_expenses[j] != 0 & test$package_data_noncash_expenses[j] == 0) ind[j] <- j
}

ind <- ind[!is.na(ind)]

cons <- 0.036890546
for (i in ind) {
  test$LR[i] <- test$nonpackage_data_expenses[i]*cons/4510.638 + ZeroUse
}

smape(test$data_usage_volume, test$LR)

write.csv(test, 'Model20(LR).csv', row.names = FALSE)

# %%
#############Model 21: MARS
library(xgboost)
library(tidymodels)
library(modeltime)
library(tidyverse)
library(lubridate)
library(timetk)
library(earth)

#data <- read.csv('Train+test(Ordered).csv')
#test <- read.csv('MCIRD_aaic2021_test_week2.csv')
data <- read.csv('MCIRD_aaic2021_train.csv')
test <- read.csv('MCIRD_aaic2021_test_week1_with_target.csv')

id <- unique(test$subscriber_ecid)
lt <- length(test$subscriber_ecid)

MARS <- rep(0, lt)
test <- cbind(test, MARS)

for(i in id){
  y <- ts(data$data_usage_volume[data$subscriber_ecid == i])
  l <- length(y)
  ds <- seq(from = as.Date("2017-01-01"), length.out = l, by = 'day')
  MARS_data <- cbind(ds, y)
  MARS_data <- as_tibble(MARS_data)
  MARS_data$ds <- as.Date(ds)
  MARS_Model <- mars(mode = "regression") %>%
    set_engine("earth") 
  recipe_spec <- recipe(y ~ ds, data = MARS_data) %>%
    step_date(ds, features = "month", ordinal = FALSE) %>%
    step_mutate(date_num = as.numeric(ds)) %>%
    step_normalize(date_num) %>%
    step_rm(ds)
  wflw_fit_mars <- workflow() %>%
    add_recipe(recipe_spec) %>%
    add_model(MARS_Model) %>%
    fit(MARS_data)
  models_tbl <- modeltime_table(wflw_fit_mars)
  y <- ts(test$data_usage_volume[test$subscriber_ecid == i])
  lu <- length(y)
  ds <- seq(from = as.Date(MARS_data$ds[l]), length.out = lu, by = 'day')
  MARS_data_t <- cbind(ds, y)
  MARS_data_t <- as_tibble(MARS_data_t)
  MARS_data_t$ds <- as.Date(ds)
  calibration_tbl <- models_tbl %>%
    modeltime_calibrate(new_data = MARS_data_t)
  pred <- modeltime_forecast(calibration_tbl, new_data = MARS_data_t, actual_data = MARS_data)
  test$MARS[test$subscriber_ecid==i] <- as.vector(pred$.value[(l+1):(l+lu)])
}

ZeroUse <- as.numeric(-0.0139766307813943)
for (i in 1:lt) {
  if (test$is_data_usage_nonzero[i] == 0) test$MARS[i] <- ZeroUse
}

ind <- c()
for (j in 1:lt) {
  if (test$data_cash_expenses[j] == 0 & test$nonpackage_data_expenses[j] != 0 & test$package_data_noncash_expenses[j] == 0) ind[j] <- j
}

ind <- ind[!is.na(ind)]

cons <- 0.036890546
for (i in ind) {
  test$MARS[i] <- test$nonpackage_data_expenses[i]*cons/4510.638 + ZeroUse
}

smape(test$data_usage_volume, test$MARS)

write.csv(test, 'Model21(MARS).csv', row.names = FALSE)

# %%
#############Model 22: LSTM
data <- read.csv('MCIRD_aaic2021_train.csv')
test <- read.csv('MCIRD_aaic2021_test_week1_with_target.csv')

library(keras)
library(tensorflow)


  
  Series = data$data_usage_volume[data$subscriber_ecid=="-In6IG8Z3Ts6f"]  # your time series 
  # transform data to stationarity
  diffed = diff(Series, differences = 1)
  
  
  # create a lagged dataset, i.e to be supervised learning
  
  lags <- function(x, k){
    
    lagged =  c(rep(NA, k), x[1:(length(x)-k)])
    DF = as.data.frame(cbind(lagged, x))
    colnames(DF) <- c( paste0('x-', k), 'x')
    DF[is.na(DF)] <- 0
    return(DF)
  }
  supervised = lags(diffed, 1)
  
  
  ## split into train and test sets
  
  N = nrow(supervised)
  n = round(N *0.9, digits = 0)
  train = supervised[1:n, ]
  test  = supervised[(n+1):N,  ]
  
  
  ## scale data
  normalize <- function(train, test, feature_range = c(0, 1)) {
    x = train
    fr_min = feature_range[1]
    fr_max = feature_range[2]
    std_train = ((x - min(x) ) / (max(x) - min(x)  ))
    std_test  = ((test - min(x) ) / (max(x) - min(x)  ))
    
    scaled_train = std_train *(fr_max -fr_min) + fr_min
    scaled_test = std_test *(fr_max -fr_min) + fr_min
    
    return( list(scaled_train = as.vector(scaled_train), scaled_test = as.vector(scaled_test) ,scaler= c(min =min(x), max = max(x))) )
    
  }
  
  
  ## inverse-transform
  inverter = function(scaled, scaler, feature_range = c(0, 1)){
    min = scaler[1]
    max = scaler[2]
    n = length(scaled)
    mins = feature_range[1]
    maxs = feature_range[2]
    inverted_dfs = numeric(n)
    
    for( i in 1:n){
      X = (scaled[i]- mins)/(maxs - mins)
      rawValues = X *(max - min) + min
      inverted_dfs[i] <- rawValues
    }
    return(inverted_dfs)
  }
  
  
  Scaled = normalize(train, test, c(-1, 1))
  
  y_train = Scaled$scaled_train[, 2]
  x_train = Scaled$scaled_train[, 1]
  
  y_test = Scaled$scaled_test[, 2]
  x_test = Scaled$scaled_test[, 1]
  
  ## fit the model
  
  dim(x_train) <- c(length(x_train), 1, 1)
  dim(x_train)
  X_shape2 = dim(x_train)[2]
  X_shape3 = dim(x_train)[3]
  batch_size = 1
  units = 1
  
  model <- keras_model_sequential() 
  model%>%
    layer_lstm(units, batch_input_shape = c(batch_size, X_shape2, X_shape3), stateful= TRUE)%>%
    layer_dense(units = 1)
  
  
  
  model %>% compile(
    loss = 'mean_squared_error',
    optimizer = optimizer_adam( learning_rate = 0.02 , decay = 1e-6 ),  
    metrics = c('accuracy')
  )
  
  
  
  summary(model)
  
  nb_epoch = Epochs   
  for(i in 1:nb_epoch ){
    model %>% fit(x_train, y_train, epochs=1, batch_size=batch_size, verbose=1, shuffle=FALSE)
    model %>% reset_states()
  }
  
  
  L = length(x_test)
  dim(x_test) = c(length(x_test), 1, 1)
  
  scaler = Scaled$scaler

  predictions = numeric(L)
  for(i in 1:L){
    X = x_test[i , , ]
    dim(X) = c(1,1,1)
    # forecast
    yhat = model %>% predict(X, batch_size=batch_size)
    
    # invert scaling
    yhat = inverter(yhat, scaler,  c(-1, 1))
    
    # invert differencing
    yhat  = yhat + Series[(n+i)] 
    
    # save prediction
    predictions[i] <- yhat
  }
  predictions

# %%
#############Combining
Results<-read.csv(file.choose())

res <- Results[, -1]
comp <- aggregate(. ~ subscriber_ecid, data = res, FUN = "mean")
id <- comp$subscriber_ecid

for (d in id) {
  for (m in 2:10) {
    comp[comp$subscriber_ecid == d, m] <- smape(res[res$subscriber_ecid == d, m], res[res$subscriber_ecid == d, 11])
  }
}

comp <- comp[,-11]
write.csv(comp, 'Model_Results_SMAPE.csv', row.names = FALSE)

Ens <- rep(0, 662)
res < -cbind(res, Ens)
for (d in id) {
  for (b in 2:10) {
    best <- max(comp[comp$subscriber_ecid == d, 2:10])
    if (comp[comp$subscriber_ecid==d,b] == best) res[res$subscriber_ecid == d, 12] <- res[res$subscriber_ecid == d, b]
  }
}

write.csv(res, 'Model_Results_Ens.csv', row.names = FALSE)

smape(res$Ens,res$Real)
